# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/NazariAmin/AppleCourseApp/blob/master/MLProject.ipynb)

# %%
ls
# Out:
# sample_data/

# %%
# %cd
# !git clone https://github.com/tensorflow/models.git
# Out:
# /root
# Cloning into 'models'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 21751 (delta 0), reused 0 (delta 0), pack-reused 21745
# Receiving objects: 100% (21751/21751), 559.39 MiB | 34.14 MiB/s, done.
# Resolving deltas: 100% (12807/12807), done.
# Checking out files: 100% (2809/2809), done.

# %%
# %cd models/research/deeplab/
# !sh ./local_test.sh

model_dir = '/content/models/research/deeplab/datasets/pascal_voc_seg/exp/train_on_trainval_set/export/'
# Out:
# /root/models/research/deeplab
# testBuildDeepLabWithDensePredictionCell (__main__.DeeplabModelTest) ... ok
# testBuildDeepLabv2 (__main__.DeeplabModelTest) ... ok
# testForwardpassDeepLabv3plus (__main__.DeeplabModelTest) ... ok
# testWrongDeepLabVariant (__main__.DeeplabModelTest) ... ok
# test_session (__main__.DeeplabModelTest)
# Use cached_session instead. ... ok
#
# ----------------------------------------------------------------------
# Ran 5 tests in 21.603s
#
# OK
# ...
# --2018-10-12 17:41:37--  http://host.robots.ox.ac.uk/pascal/VOC/voc2012//VOCtrainval_11-May-2012.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1999639040 (1.9G) [application/x-tar]
# Saving to: ‘VOCtrainval_11-May-2012.tar’
#
# VOCtrainval_11-May- 100%[===================>]   1.86G  9.19MB/s    in 3m 34s
#
# ...
